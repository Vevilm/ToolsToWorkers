-- %% [markdown]
-- # [ToolsToWorkers]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ToolsToWorkers]    Script Date: 20.10.2024 0:30:42 ******/
CREATE DATABASE [ToolsToWorkers]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ToolsToWorkers', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS01\MSSQL\DATA\ToolsToWorkers.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ToolsToWorkers_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS01\MSSQL\DATA\ToolsToWorkers_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [ToolsToWorkers] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ToolsToWorkers].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ToolsToWorkers] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET ARITHABORT OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ToolsToWorkers] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ToolsToWorkers] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ToolsToWorkers] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ToolsToWorkers] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [ToolsToWorkers] SET  MULTI_USER 
GO
ALTER DATABASE [ToolsToWorkers] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ToolsToWorkers] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ToolsToWorkers] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ToolsToWorkers] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ToolsToWorkers] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ToolsToWorkers] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [ToolsToWorkers] SET QUERY_STORE = ON
GO
ALTER DATABASE [ToolsToWorkers] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Articles]

-- %%
USE [ToolsToWorkers]
GO

-- %%
/****** Object:  Table [dbo].[Articles]    Script Date: 20.10.2024 0:30:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Articles](
	[ID] [nvarchar](450) NOT NULL,
	[Name] [nvarchar](max) NOT NULL,
	[Description] [nvarchar](max) NOT NULL,
	[Weight] [float] NOT NULL,
 CONSTRAINT [PK_Articles] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Storages]

-- %%
/****** Object:  Table [dbo].[Storages]    Script Date: 20.10.2024 0:30:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Storages](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](max) NOT NULL,
	[Type] [nvarchar](max) NOT NULL,
	[Status] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_Storages] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tools]

-- %%
/****** Object:  Table [dbo].[Tools]    Script Date: 20.10.2024 0:30:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tools](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[StorageID] [int] NOT NULL,
	[ArticleID] [nvarchar](max) NOT NULL,
	[Status] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_Tools] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ToolsView]

-- %%
/****** Object:  View [dbo].[ToolsView]    Script Date: 20.10.2024 0:30:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[ToolsView] AS
SELECT
Tools.ID AS ID,
Articles.Name AS Name,
Storages.Name AS Storage,
Tools.Status AS Status,
Articles.ID AS Article,
Articles.Description AS Description,
Articles.Weight AS Weight,
StorageID,
Storages.Type AS Type,
Storages.Status AS StorageStatus
FROM Tools INNER JOIN Storages ON Tools.StorageID = Storages.ID
INNER JOIN Articles ON Tools.ArticleID = Articles.ID
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 20.10.2024 0:30:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ToolRequests]

-- %%
/****** Object:  Table [dbo].[ToolRequests]    Script Date: 20.10.2024 0:30:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ToolRequests](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[WorkerID] [int] NOT NULL,
	[ToolID] [int] NOT NULL,
	[Status] [nvarchar](max) NOT NULL,
	[Requested] [datetime2](7) NOT NULL,
	[Returned] [datetime2](7) NOT NULL,
 CONSTRAINT [PK_ToolRequests] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 20.10.2024 0:30:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Surname] [nvarchar](max) NOT NULL,
	[Name] [nvarchar](max) NOT NULL,
	[Patronymic] [nvarchar](max) NOT NULL,
	[Role] [nvarchar](max) NOT NULL,
	[Status] [nvarchar](max) NOT NULL,
	[Login] [nvarchar](max) NOT NULL,
	[HashedPassword] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_Users] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [ToolsToWorkers]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ToolsToWorkers] SET  READ_WRITE 
GO
